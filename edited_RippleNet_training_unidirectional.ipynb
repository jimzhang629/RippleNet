# %% [markdown]
# <a href="https://colab.research.google.com/github/jimzhang629/RippleNet/blob/master/edited_RippleNet_training_unidirectional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RippleNet_training_unidirectional
# Training of simple unidirectional recurrent neural network (RNN) implementation in `tensorflow.keras` using LSTM (long short-term memory) layers to identify time of occurence of sharp wave ripple (SPW-R) events in temporal LFP data.
#
# Author: Espen Hagen (<https://github.com/espenhgn>)
#
# LICENSE: <https://github.com/CINPLA/RippleNet/blob/master/LICENSE>

# %%
# allow running on Google Colab for training using Google Drive for file access
try:
    from google.colab import drive
    drive.mount('/content/gdrive')
    # %cd gdrive/My\ Drive/RippleNet
    # %tensorflow_version 2.x
except:
    pass
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/My Drive/RippleNet'
# /content/gdrive/My Drive/RippleNet

# %%
# %matplotlib inline

# %%
# import modules
import os
import numpy as np
import scipy.signal as ss
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib import colors
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import plot_model
import ripplenet.edited_models
import h5py
import pickle
import random

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14973033874769795810
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14674281152
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 18393071036144580681
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# ]

# %%
print(tf.__version__)
print(tf.test.gpu_device_name())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.4.1
# /device:GPU:0
# Num GPUs Available:  1

# %%
# set random seeds with some additional environment variables to ensure deterministic output
random_seed = 208
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['PYTHONHASHSEED']=str(random_seed)
random.seed(random_seed)
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# %%
# select dataset (may have generated different sets.)
dataset_index = 0

# %% [markdown]
# # Load training/validation data

# %%
# select species for training/validation data (mouse, rat or both)
mouse = True
rat = False

# %%
# output destination
output_folder = 'trained_networks'
if not os.path.isdir(output_folder):
    os.mkdir(output_folder)
    
# prefix for trained network files (training loss/MSE, weights, `best' weights)
rnn_prefix = 'ripplenet_unidirectional'

# %%
if mouse:
    # training and validation files
    f_name_train = 'train_{:02}.h5'
    f_name_val = 'validation_{:02}.h5'
    
    # training data
    f = h5py.File(os.path.join('data', 
                               f_name_train.format(dataset_index)), 
                  'r')
    X_train = np.expand_dims(f['X0'][:], -1)
    Y_train = f['Y'][:]
    
    f.close()

    # validation data
    f = h5py.File(os.path.join('data', 
                               f_name_val.format(dataset_index)), 
                  'r')
    X_val = np.expand_dims(f['X0'][:], -1)
    Y_val = f['Y'][:]
    f.close()
    
    # load some data for plotting
    f = h5py.File(os.path.join('data', 
                               f_name_val.format(dataset_index)), 'r')
    X0 = f['X0'][:]
    X1 = f['X1'][:]
    S = f['S'][:]
    Y = f['Y'][:]
    S_freqs = f['S_freqs'][:]
    print(f)
    f.close()


    print(X_train.shape)
    print(Y_train.shape)
    print(X_val.shape)
    print(Y_val.shape)
# Out:
# <HDF5 file "validation_00.h5" (mode r)>
# (4175, 1250, 1)
# (4175, 1250, 1)
# (200, 1250, 1)
# (200, 1250, 1)

# %%
def prime_factors(n):
    i = 2
    factors = []
    while i * i <= n:
        if n % i:
            i += 1
        else:
            n //= i
            factors.append(i)
    if n > 1:
        factors.append(n)
    return factors

# %%
print(X_train.shape[0])
print("prime factorization of X_train[0] * X_train[1] :", prime_factors(X_train.shape[0]*X_train.shape[1]))
print("prime factorization of X_val[0] * X_val[1] :", prime_factors(X_val.shape[0]*X_val.shape[1]))
print("The common factors are: 1, 2, 5, 10, 25, 50, 125, 250, 625, 1250, 3125, 6250, 15625, 31250")
# Out:
# 4175
# prime factorization of X_train[0] * X_train[1] : [2, 5, 5, 5, 5, 5, 5, 167]
# prime factorization of X_val[0] * X_val[1] : [2, 2, 2, 2, 5, 5, 5, 5, 5, 5]
# The common factors are: 1, 2, 5, 10, 25, 50, 125, 250, 625, 1250, 3125, 6250, 15625, 31250

# %%
samples_per_time_segment = 625 #how many samples per each time segment. Some combination of the prime factors.
time_segment = samples_per_time_segment / 1250 #how many seconds are the time segments we're training on
train_first_dim = int(X_train.shape[0]*X_train.shape[1] / samples_per_time_segment) #must make sure that this is evenly divisible
val_first_dim = int(X_val.shape[0]*X_val.shape[1] / samples_per_time_segment)
print(val_first_dim)
print(time_segment)
# Out:
# 400
# 0.5

# %%
reshaped_X_train = np.reshape(X_train, (train_first_dim, samples_per_time_segment, 1))
reshaped_Y_train = np.reshape(Y_train, (train_first_dim, samples_per_time_segment, 1))
reshaped_X_val = np.reshape(X_val, (val_first_dim, samples_per_time_segment, 1))
reshaped_Y_val = np.reshape(Y_val, (val_first_dim, samples_per_time_segment, 1))
#print(reshaped_X_train)
print(reshaped_X_train.shape)
print(reshaped_Y_train.shape)

print(reshaped_X_val.shape)
print(reshaped_Y_val.shape)
# Out:
# (8350, 625, 1)
# (8350, 625, 1)
# (400, 625, 1)
# (400, 625, 1)

# %%
 # Add rat training/validation data to sets
if rat and mouse:
    # rat 
    f_name_train = 'train_tingley_{:02}.h5'
    f_name_val = 'validation_tingley_{:02}.h5'

    # training data
    f = h5py.File(os.path.join('data', 
                            f_name_train.format(dataset_index)), 
                'r')
    X_train = np.concatenate((X_train, np.expand_dims(f['X0'][:], -1)))
    Y_train = np.concatenate((Y_train, f['Y'][:]))
    f.close()

    # validation data
    f = h5py.File(os.path.join('data', 
                            f_name_val.format(dataset_index)), 
                'r')
    X_val = np.concatenate((X_val, np.expand_dims(f['X0'][:], -1)))
    Y_val = np.concatenate((Y_val, f['Y'][:]))
    f.close()
    
    # load some data for plotting
    f = h5py.File(os.path.join('data', 
                            f_name_val.format(dataset_index)), 'r')
    X0 = np.concatenate((X0, f['X0'][:]))
    X1 = np.concatenate((X1, f['X1'][:]))
    S = np.concatenate((S, f['S'][:]))
    Y = np.concatenate((Y, f['Y'][:]))
    f.close()

# %%
if rat and not mouse:
    # rat 
    f_name_train = 'train_tingley_{:02}.h5'
    f_name_val = 'validation_tingley_{:02}.h5'

    # training data
    f = h5py.File(os.path.join('..', 'data', 
                               f_name_train.format(dataset_index)), 
                  'r')
    X_train = np.expand_dims(f['X0'][:], -1)
    Y_train = f['Y'][:]
    f.close()

    # validation data
    f = h5py.File(os.path.join('data', 
                               f_name_val.format(dataset_index)), 
                  'r')
    X_val = np.expand_dims(f['X0'][:], -1)
    Y_val = f['Y'][:]
    f.close()

    # load some data for plotting
    f = h5py.File(os.path.join('data', 
                               f_name_val.format(dataset_index)), 'r')
    X0 = f['X0'][:]
    X1 = f['X1'][:]
    S = f['S'][:]
    Y = f['Y'][:]
    S_freqs = f['S_freqs'][:]
    f.close()

# %%
# needed parameters
Fs = 1250 # Hz, sampling freq
time = np.arange(X0.shape[1]) / Fs

# center raw data
X0 = (X0.T - X0.mean(axis=-1)).T

# total number of samples
n_samples = X0.shape[0]

# %%
# plot all labels and raw data matrices
fig, axes = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(12, 12))
axes[0].pcolormesh(time, np.arange(n_samples), Y[:, :, 0])
axes[0].set_ylabel('#')
axes[0].set_title('labels (y)')
axes[1].pcolormesh(time, np.arange(n_samples), X0, vmin=-X0.std()*3, vmax=X0.std()*3)
axes[1].set_ylabel('#')
axes[1].set_xlabel('t (s)')
axes[1].set_title('raw data (X)')
for ax in axes:
    ax.axis(ax.axis('tight'))

# %%
# plot wavelet spectrograms vs. labels and raw data for some samples
for i in range(5):
    gs = GridSpec(2, 1)
    fig = plt.figure(figsize=(12, 6))
    ax0 = fig.add_subplot(gs[0, 0])
    ax0.plot(time, X0[i, ], label='$X(t)$')
    ax0.plot(time, X1[i, ], label=r'$\phi_\mathrm{bp}(t)$')
    ax0.plot(time, Y[i, :, 0], label='label ($y$)' )
    ax0.legend(ncol=2)
    ax0.axis(ax0.axis('tight'))
    ax0.set_title('label, raw data and spectrograms')
    plt.setp(ax0.get_xticklabels(), visible=False)
    
    ax1 = fig.add_subplot(gs[1:, 0], sharex=ax0)
    vmin, vmax = np.exp(np.percentile(np.log(S), [1, 99]))
    im = ax1.pcolormesh(time, S_freqs, S[i, ].T, norm=colors.LogNorm(vmin=vmin, vmax=vmax),
                        cmap='inferno')
    ax1.axis(ax1.axis('tight'))
    ax1.set_ylabel('$f$ (Hz)')
    ax1.set_xlabel('$t$ (s)')

# %% [markdown]
# # Set up recurrent neural network

# %%
model = ripplenet.edited_models.get_unidirectional_LSTM_model(input_shape=(None, reshaped_X_train.shape[2]), 
                                                       layer_sizes=[20, 10, 5, 5],
                                                       seed=random_seed+1)

# %%
model.summary()
# Out:
# Model: "RippleNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, 1)]         0
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, None, 1)           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 20)          220
# _________________________________________________________________
# dropout (Dropout)            (None, None, 20)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 10)          2210
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 10)          40
# _________________________________________________________________
# activation (Activation)      (None, None, 10)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 10)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, None, 5)           320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 5)           20
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, 5)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 5)           220
# _________________________________________________________________
# dropout_3 (Dropout)          (None, None, 5)           0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, 5)           20
# _________________________________________________________________
# dropout_4 (Dropout)          (None, None, 5)           0
# _________________________________________________________________
# time_distributed (TimeDistri (None, None, 1)           6
# =================================================================
# Total params: 3,056
# Trainable params: 3,016
# Non-trainable params: 40
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True, expand_nested=True)

# %%
# callback for model checkpoints when validation MSE improves
filepath = os.path.join(output_folder, '{}_best_random_seed{}.h5'.format(rnn_prefix, random_seed))
checkpoint_best = keras.callbacks.ModelCheckpoint(filepath, monitor='val_mse', 
                                             verbose=1, save_best_only=True, 
                                             mode='min')
# MSE/loss callback to .csv
callback_hist = keras.callbacks.CSVLogger(os.path.join(output_folder, 
                                                       '{}_history_random_seed{}.csv'.format(rnn_prefix, 
                                                                                             random_seed)))
callbacks_list = [checkpoint_best, callback_hist]

# %%
# train model
history = model.fit(reshaped_X_train, reshaped_Y_train, 
                    batch_size=20, 
                    epochs=50, 
                    callbacks=callbacks_list,
                    validation_data=(reshaped_X_val, reshaped_Y_val))
# Out:
# Epoch 1/50
# 418/418 [==============================] - 20s 40ms/step - loss: 0.3986 - mse: 0.1267 - val_loss: 0.1653 - val_mse: 0.0442
#
# Epoch 00001: val_mse improved from inf to 0.04424, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 2/50
# 418/418 [==============================] - 16s 39ms/step - loss: 0.1503 - mse: 0.0396 - val_loss: 0.1195 - val_mse: 0.0324
#
# Epoch 00002: val_mse improved from 0.04424 to 0.03239, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 3/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1393 - mse: 0.0368 - val_loss: 0.1183 - val_mse: 0.0324
#
# Epoch 00003: val_mse did not improve from 0.03239
# Epoch 4/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1370 - mse: 0.0363 - val_loss: 0.1148 - val_mse: 0.0317
#
# Epoch 00004: val_mse improved from 0.03239 to 0.03169, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 5/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1360 - mse: 0.0359 - val_loss: 0.1141 - val_mse: 0.0315
#
# Epoch 00005: val_mse improved from 0.03169 to 0.03154, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 6/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1301 - mse: 0.0345 - val_loss: 0.1088 - val_mse: 0.0299
#
# Epoch 00006: val_mse improved from 0.03154 to 0.02992, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 7/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1260 - mse: 0.0334 - val_loss: 0.1231 - val_mse: 0.0321
#
# Epoch 00007: val_mse did not improve from 0.02992
# Epoch 8/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1259 - mse: 0.0335 - val_loss: 0.1016 - val_mse: 0.0282
#
# Epoch 00008: val_mse improved from 0.02992 to 0.02816, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 9/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1233 - mse: 0.0328 - val_loss: 0.1063 - val_mse: 0.0290
#
# Epoch 00009: val_mse did not improve from 0.02816
# Epoch 10/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1234 - mse: 0.0329 - val_loss: 0.1037 - val_mse: 0.0284
#
# Epoch 00010: val_mse did not improve from 0.02816
# Epoch 11/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1205 - mse: 0.0322 - val_loss: 0.0971 - val_mse: 0.0267
#
# Epoch 00011: val_mse improved from 0.02816 to 0.02669, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 12/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1199 - mse: 0.0321 - val_loss: 0.1046 - val_mse: 0.0290
#
# Epoch 00012: val_mse did not improve from 0.02669
# Epoch 13/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1173 - mse: 0.0315 - val_loss: 0.0947 - val_mse: 0.0259
#
# Epoch 00013: val_mse improved from 0.02669 to 0.02589, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 14/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1144 - mse: 0.0308 - val_loss: 0.0950 - val_mse: 0.0260
#
# Epoch 00014: val_mse did not improve from 0.02589
# Epoch 15/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1142 - mse: 0.0307 - val_loss: 0.0957 - val_mse: 0.0263
#
# Epoch 00015: val_mse did not improve from 0.02589
# Epoch 16/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1136 - mse: 0.0304 - val_loss: 0.0934 - val_mse: 0.0256
#
# Epoch 00016: val_mse improved from 0.02589 to 0.02563, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 17/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1150 - mse: 0.0308 - val_loss: 0.0991 - val_mse: 0.0277
#
# Epoch 00017: val_mse did not improve from 0.02563
# Epoch 18/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1146 - mse: 0.0308 - val_loss: 0.0910 - val_mse: 0.0249
#
# Epoch 00018: val_mse improved from 0.02563 to 0.02490, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 19/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1143 - mse: 0.0307 - val_loss: 0.0924 - val_mse: 0.0258
#
# Epoch 00019: val_mse did not improve from 0.02490
# Epoch 20/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1126 - mse: 0.0302 - val_loss: 0.0904 - val_mse: 0.0250
#
# Epoch 00020: val_mse did not improve from 0.02490
# Epoch 21/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1130 - mse: 0.0304 - val_loss: 0.0929 - val_mse: 0.0255
#
# Epoch 00021: val_mse did not improve from 0.02490
# Epoch 22/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1147 - mse: 0.0307 - val_loss: 0.0913 - val_mse: 0.0253
#
# Epoch 00022: val_mse did not improve from 0.02490
# Epoch 23/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1138 - mse: 0.0306 - val_loss: 0.1022 - val_mse: 0.0290
#
# Epoch 00023: val_mse did not improve from 0.02490
# Epoch 24/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1102 - mse: 0.0295 - val_loss: 0.0917 - val_mse: 0.0254
#
# Epoch 00024: val_mse did not improve from 0.02490
# Epoch 25/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1106 - mse: 0.0296 - val_loss: 0.0927 - val_mse: 0.0255
#
# Epoch 00025: val_mse did not improve from 0.02490
# Epoch 26/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1110 - mse: 0.0298 - val_loss: 0.0895 - val_mse: 0.0247
#
# Epoch 00026: val_mse improved from 0.02490 to 0.02472, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 27/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1141 - mse: 0.0307 - val_loss: 0.0952 - val_mse: 0.0264
#
# Epoch 00027: val_mse did not improve from 0.02472
# Epoch 28/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1104 - mse: 0.0296 - val_loss: 0.0898 - val_mse: 0.0248
#
# Epoch 00028: val_mse did not improve from 0.02472
# Epoch 29/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1101 - mse: 0.0295 - val_loss: 0.0893 - val_mse: 0.0248
#
# Epoch 00029: val_mse did not improve from 0.02472
# Epoch 30/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1118 - mse: 0.0301 - val_loss: 0.0900 - val_mse: 0.0251
#
# Epoch 00030: val_mse did not improve from 0.02472
# Epoch 31/50
# 418/418 [==============================] - 16s 37ms/step - loss: 0.1088 - mse: 0.0292 - val_loss: 0.0908 - val_mse: 0.0249
#
# Epoch 00031: val_mse did not improve from 0.02472
# Epoch 32/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1099 - mse: 0.0295 - val_loss: 0.0893 - val_mse: 0.0248
#
# Epoch 00032: val_mse did not improve from 0.02472
# Epoch 33/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1101 - mse: 0.0295 - val_loss: 0.0960 - val_mse: 0.0274
#
# Epoch 00033: val_mse did not improve from 0.02472
# Epoch 34/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1089 - mse: 0.0292 - val_loss: 0.0998 - val_mse: 0.0274
#
# Epoch 00034: val_mse did not improve from 0.02472
# Epoch 35/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1102 - mse: 0.0296 - val_loss: 0.0878 - val_mse: 0.0243
#
# Epoch 00035: val_mse improved from 0.02472 to 0.02429, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 36/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1097 - mse: 0.0294 - val_loss: 0.0882 - val_mse: 0.0245
#
# Epoch 00036: val_mse did not improve from 0.02429
# Epoch 37/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1083 - mse: 0.0292 - val_loss: 0.0907 - val_mse: 0.0252
#
# Epoch 00037: val_mse did not improve from 0.02429
# Epoch 38/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1085 - mse: 0.0291 - val_loss: 0.0880 - val_mse: 0.0242
#
# Epoch 00038: val_mse improved from 0.02429 to 0.02422, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 39/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1123 - mse: 0.0303 - val_loss: 0.0878 - val_mse: 0.0243
#
# Epoch 00039: val_mse did not improve from 0.02422
# Epoch 40/50
# 418/418 [==============================] - 16s 37ms/step - loss: 0.1102 - mse: 0.0296 - val_loss: 0.0882 - val_mse: 0.0242
#
# Epoch 00040: val_mse did not improve from 0.02422
# Epoch 41/50
# 418/418 [==============================] - 16s 37ms/step - loss: 0.1103 - mse: 0.0296 - val_loss: 0.0895 - val_mse: 0.0248
#
# Epoch 00041: val_mse did not improve from 0.02422
# Epoch 42/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1089 - mse: 0.0291 - val_loss: 0.0889 - val_mse: 0.0247
#
# Epoch 00042: val_mse did not improve from 0.02422
# Epoch 43/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1079 - mse: 0.0289 - val_loss: 0.0878 - val_mse: 0.0241
#
# Epoch 00043: val_mse improved from 0.02422 to 0.02412, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 44/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1114 - mse: 0.0298 - val_loss: 0.0953 - val_mse: 0.0269
#
# Epoch 00044: val_mse did not improve from 0.02412
# Epoch 45/50
# 418/418 [==============================] - 16s 37ms/step - loss: 0.1087 - mse: 0.0292 - val_loss: 0.0878 - val_mse: 0.0243
#
# Epoch 00045: val_mse did not improve from 0.02412
# Epoch 46/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1087 - mse: 0.0292 - val_loss: 0.0869 - val_mse: 0.0239
#
# Epoch 00046: val_mse improved from 0.02412 to 0.02389, saving model to trained_networks/ripplenet_unidirectional_best_random_seed208.h5
# Epoch 47/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1073 - mse: 0.0287 - val_loss: 0.0931 - val_mse: 0.0261
#
# Epoch 00047: val_mse did not improve from 0.02389
# Epoch 48/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1096 - mse: 0.0295 - val_loss: 0.0922 - val_mse: 0.0260
#
# Epoch 00048: val_mse did not improve from 0.02389
# Epoch 49/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1091 - mse: 0.0293 - val_loss: 0.0886 - val_mse: 0.0244
#
# Epoch 00049: val_mse did not improve from 0.02389
# Epoch 50/50
# 418/418 [==============================] - 16s 38ms/step - loss: 0.1076 - mse: 0.0288 - val_loss: 0.0887 - val_mse: 0.0245
#
# Epoch 00050: val_mse did not improve from 0.02389

# %%
# save history to a pickle so we can load it later
with open(os.path.join(output_folder, '{}_history_random_seed{}.pkl'.format(rnn_prefix, random_seed)
                      ), 'wb') as f:
    pickle.dump(history.history, f)

# %%
plt.figure(figsize=(12, 12))
plt.semilogy(history.history['loss'], '-o', label='loss')
plt.semilogy(history.history['val_loss'], '-o', label='val_loss')
plt.semilogy(history.history['mse'], '-o', label='mse')
plt.semilogy(history.history['val_mse'], '-o', label='val_mse')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('MSE')
plt.title('training/validation MSE')
# Out:
# Text(0.5, 1.0, 'training/validation MSE')

# %%
# Save the trained model
model.save(os.path.join(output_folder, '{}_random_seed{}.h5'.format(rnn_prefix, random_seed)))
